# %% [markdown]
# <a href="https://colab.research.google.com/github/presannak/Virtual-Academy/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
s=np.array([1,2,3])
print(type(s))
t=pd.Series([1,2,3,4,5])
print(type(t))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
t[2]
# Out:
# 3

# %%
t.iloc[2]
# Out:
# 3

# %%
t.loc[3]
# Out:
# 4

# %%
t[2]
# Out:
# 3

# %%
t.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
v=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
v
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
vi=pd.Series([1,2,3,4,5],index=['a','b','a','d','e'])
vi.loc['a']
# Out:
# a    1
# a    3
# dtype: int64

# %%
data = [['Alex',10,'23-05-2000'],['Bob',None,None],['Pres',19,'13-01-2004']]
data
# Out:
# [['Alex', 10, '23-05-2000'], ['Bob', None, None], ['Pres', 19, '13-01-2004']]

# %%
df=pd.DataFrame(data)
df
# Out:
#       0     1           2
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None
# 2  Pres  19.0  13-01-2004

# %%
df[0:1]
# Out:
#       0     1           2
# 0  Alex  10.0  23-05-2000

# %%
df[0:2]
# Out:
#       0     1           2
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None

# %%
df[0][0]
# Out:
# 'Alex'

# %%
df[[0,2]]
# Out:
#       0           2
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df[1:2]
# Out:
#      0   1     2
# 1  Bob NaN  None

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])
df
# Out:
#    Name   Age         DOB
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None
# 2  Pres  19.0  13-01-2004

# %%
df['Name']
# Out:
# 0    Alex
# 1     Bob
# 2    Pres
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    10.0
# 1     NaN
# 2    19.0
# Name: Age, dtype: float64

# %%
df['DOB'][2]
# Out:
# '13-01-2004'

# %%
df.iloc[0,0]
# Out:
# 'Alex'

# %%
df.loc[0,'Name']
# Out:
# 'Alex'

# %%
s=pd.Series([1,2,3])
s.plot.bar()
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()
type(s)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    Name   Age         DOB
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None
# 2  Pres  19.0  13-01-2004

# %%
df.head(1)
# Out:
#    Name   Age         DOB
# 0  Alex  10.0  23-05-2000

# %%
df.tail(1)
# Out:
#    Name   Age         DOB
# 2  Pres  19.0  13-01-2004

# %%
df.tail(-2)
# Out:
#    Name   Age         DOB
# 2  Pres  19.0  13-01-2004

# %%
# None,' ','','-','?','Nil',np.nan (not a number)

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     1
# DOB     1
# dtype: int64

# %%
df.dropna()
# Out:
#    Name   Age         DOB
# 0  Alex  10.0  23-05-2000
# 2  Pres  19.0  13-01-2004

# %%
df
# Out:
#    Name   Age         DOB
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None
# 2  Pres  19.0  13-01-2004

# %%
df.drop?

# %%
df.drop(['Age'],axis=1,inplace=True)

# %%
df
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df.drop([0,2])
# Out:
#   Name   DOB
# 1  Bob  None

# %%
a=np.array([10,12,13,44,56])
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
a>40
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>40]
# Out:
# array([44, 56])

# %%
a[a%2!=0]
# Out:
# array([13])

# %%
df
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   DOB     2 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
df['Name'].str.contains('P')
# Out:
# 0    False
# 1    False
# 2     True
# Name: Name, dtype: bool

# %%
df
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 2)
# 6
# [RangeIndex(start=0, stop=3, step=1), Index(['Name', 'DOB'], dtype='object')]
# 2
# Name    object
# DOB     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'DOB'], dtype='object')
# [['Alex' '23-05-2000']
#  ['Bob' None]
#  ['Pres' '13-01-2004']]

# %%
df.head()
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df.tail()
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df2=pd.concat([df,df])

# %%
df2
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df.describe()
# Out:
#         Name         DOB
# count      3           2
# unique     3           2
# top     Alex  23-05-2000
# freq       1           1

# %%
df['Name']
# Out:
# 0    Alex
# 1     Bob
# 2    Pres
# Name: Name, dtype: object

# %%
df.DOB
# Out:
# 0    23-05-2000
# 1          None
# 2    13-01-2004
# Name: DOB, dtype: object

# %%
df[['Name','DOB']]
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df.loc[0][0]
# Out:
# 'Alex'

# %%
df.loc[0,'Name']
# Out:
# 'Alex'

# %%
df.loc[1,'Name']
# Out:
# 'Bob'

# %%
df.iloc[2,1]
df
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob        None
# 2  Pres  13-01-2004

# %%
df["DOB"][2]='13-1-2004'

# %%
df
# Out:
#    Name         DOB
# 0  Alex  23-05-2000
# 1   Bob    1-1-2001
# 2  Pres   13-1-2004

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/Leo_(2023_Indian_film)")
df
# Out:
# [                   Leo                                              Leo.1
#  0               Poster                                             Poster
#  1          Directed by                                   Lokesh Kanagaraj
#  2           Written by  .mw-parser-output .plainlist ol,.mw-parser-out...
#  3          Produced by               S. S. Lalit KumarJagadish Palanisamy
#  4             Starring                        VijaySanjay DuttTrishaArjun
#  5       Cinematography                                  Manoj Paramahamsa
#  6            Edited by                                       Philomin Raj
#  7             Music by                                Anirudh Ravichander
#  8   Production company                                Seven Screen Studio
#  9       Distributed by                                          see below
#  10        Release date                                    19 October 2023
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.head(10).describe(include='all')
# Out:
#          order_id   quantity     item_name choice_description item_price
# count   10.000000  10.000000            10                  7         10
# unique        NaN        NaN             8                  7          7
# top           NaN        NaN  Chicken Bowl       [Clementine]     $2.39
# freq          NaN        NaN             2                  1          2
# mean     2.500000   1.100000           NaN                NaN        NaN
# std      1.509231   0.316228           NaN                NaN        NaN
# min      1.000000   1.000000           NaN                NaN        NaN
# 25%      1.000000   1.000000           NaN                NaN        NaN
# 50%      2.500000   1.000000           NaN                NaN        NaN
# 75%      3.750000   1.000000           NaN                NaN        NaN
# max      5.000000   2.000000           NaN                NaN        NaN

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price = df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-287-b926718db947>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price = df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
df.item_price*100
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink = df[df.item_price < 1.1]

# %%
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df[df.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10) & (df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_name=='Chicken Bowl') & (df.item_price<10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.star_rating>=8) & (df.content_rating=='PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 305          8.0                                         Persepolis
# 232          8.1                                  Chungking Express
# 356          8.0                                         The Artist
# 279          8.1                    The Perks of Being a Wallflower
# 370          8.0                             Hannah and Her Sisters
# 314          8.0                            Crimes and Misdemeanors
# 379          8.0                                Edward Scissorhands
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 391          8.0                                   Edge of Tomorrow
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# ...

# %%
df[df.actors_list.str.contains('Kevin Costner')].sort_values(['duration','star_rating'], ascending=[False,True])
# Out:
#      star_rating               title content_rating      genre  duration  \
# 316          8.0                 JFK              R      Drama       189
# 339          8.0  Dances with Wolves          PG-13  Adventure       181
# 884          7.5          Open Range              R     Action       139
# 865          7.5     A Perfect World          PG-13      Crime       138
# 383          8.0    The Untouchables              R      Crime       119
# 800          7.6     Field of Dreams             PG      Drama       107
#
#                                            actors_list
# 316  [u'Kevin Costner', u'Gary Oldman', u'Jack Lemm...
# 339  [u'Kevin Costner', u'Mary McDonnell', u'Graham...
# 884  [u'Kevin Costner', u'Robert Duvall', u'Diego L...
# 865  [u'Kevin Costner', u'Clint Eastwood', u'Laura ...
# 383  [u'Kevin Costner', u'Sean Connery', u'Robert D...
# 800  [u'Kevin Costner', u'James Earl Jones', u'Ray ...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City', 'Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent == 'Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').spirit_servings.max()
# Out:
# continent
# Africa           152
# Asia             326
# Europe           373
# North America    438
# Oceania          254
# South America    302
# Name: spirit_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
